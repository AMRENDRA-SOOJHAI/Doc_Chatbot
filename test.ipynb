# %% [markdown]
# ## RAG CHATBOT----

# %%
from main import DOCUMENTS, DOC_EMBEDDINGS
from app.rag_graph import rag

# %%
question = "What is google adk?"
answer, contexts, confidence = rag(question, DOCUMENTS, DOC_EMBEDDINGS, k=2)

print(f"Q: {question}")
print(f"A: {answer}")
print(f"Confidence: {confidence}")
# Out:
# 2026-02-17 18:11:13,368 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-17 18:11:16,538 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-17 18:11:19,308 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Q: What is google adk?
# A: Google ADK (Agent Development Kit) is a flexible, modular framework for developing, deploying, and orchestrating AI agents. It is deployment-agnostic and compatible with various frameworks, optimized for Gemini and the Google ecosystem.
# Confidence: 0.59

# %%
question = "Who invented AI?"
answer, contexts, confidence = rag(question, DOCUMENTS, DOC_EMBEDDINGS, k=2)

print(f"Q: {question}")
print(f"A: {answer}")
print(f"Confidence: {confidence}")
# Out:
# 2026-02-05 17:23:02,827 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-05 17:23:05,410 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Q: Who invented AI?
# A: The context provided does not specify a single inventor of AI. It mentions Marvin Minsky as a cofounder of the MIT AI Lab, which advanced early robotics and cognitive models, but it does not attribute the invention of AI to him or any single individual. AI grew from deep mathematical ideas into practical systems, suggesting a collaborative and evolutionary development rather than a single inventor.
# Confidence: 0.62

# %%
question = "what is challange to intigrate langgraph with google adk?"
answer, contexts, confidence = rag(question, DOCUMENTS, DOC_EMBEDDINGS, k=2)

print(f"Q: {question}")
print(f"A: {answer}")
print(f"Confidence: {confidence}")
# Out:
# 2026-02-17 18:11:31,292 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-17 18:11:33,536 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Q: what is challange to intigrate langgraph with google adk?
# A: The challenge to integrate a LangGraph agent with Google ADK is that the Google ADK agent serves as the main orchestrator, and a LangGraph agent is integrated into ADK as a tool.
# Confidence: 0.49

# %%
question = "Who Is Narendra Modi?"
answer, contexts, confidence = rag(question, DOCUMENTS, DOC_EMBEDDINGS, k=2)

print(f"Q: {question}")
print(f"A: {answer}")
print(f"Confidence: {confidence}")
# Out:
# 2026-02-17 18:15:24,983 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-17 18:15:25,585 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-17 18:15:27,222 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Q: Who Is Narendra Modi?
# A: The context provided does not contain information about Narendra Modi.
# Confidence: 0.15

# %% [markdown]
# ## RAG CHATBOT API----->

# %%
import requests

question = {"question": "What is google adk?", "k": 2}

resp = requests.post(f"http://127.0.0.1:8000/ask", json=question)
print("status:", resp.status_code)
print(resp.json())
# Out:
# {'status': 'healthy', 'documents_loaded': 37, 'embeddings_ready': True, 'message': 'Ready'}
# status: 200
# {'question': 'What is google adk?', 'k': 2, 'answer': 'Google ADK, or the Google Agent Development Kit, is a flexible and modular framework for developing, deploying, and orchestrating AI agents. It is optimized for the Google ecosystem and Gemini but is also deployment-agnostic and compatible with other frameworks.', 'contexts': ['GOOGLE-ADK DOCUMENTAIO\nOverview\nGoogle Agent Development Kit ADK) is a flexible, modular framework for developing, deploying, and\norchestrating AI agents. While optimized for Gemini and the Google ecosystem, ADK is deployment-\nagnostic, and built for compatibility with other frameworks .\nWhat Makes ADK Different\nADK was designed to make agent development feel more like software development, enabling \ndevelopers to create, deploy, and orchestrate agentic architectures ranging from simple tasks to \ncomplex workflows .\nKey Features\nFeature Description Benefits\nFlexible\nOrchestration\nDeﬁne workﬂows using Sequential, Parallel, Loop agents or LLM-\ndriven dynamic routing\nPredictable pipelines + adaptive \nbehavior\nMulti-Agent Architecture Build modular, scalable applications by composing specialized \nagents in hierarchies Complex coordination and delegation\nRich Tool Ecosystem Pre-built tools, custom functions, 3rd-party libraries, agents-as-\ntools Diverse capabilities and extensibility\nDeployment Ready\nContainerize and deploy anywhere - local, Vertex AI, Cloud Run, \nDocker Production-grade scalability', 'Primary Function Controlling Agent Execution Flow\nCore Engine Predeﬁned Logic Sequence, Parallel, Loop)\nDeterminism Deterministic Predictable)\nPrimary Use Structured processes, Orchestration\nBest For Predictable execution patterns, process control\nLangGraph Agent Integration Challenge with Google ADK\nThe Google ADK agent serves as the main orchestrator.\nA LangGraph agent is integrated into ADK as a tool.'], 'confidence': 0.59}
