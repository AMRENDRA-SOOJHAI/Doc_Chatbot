# %%
from main import DOCUMENTS, DOC_EMBEDDINGS
from app.rag_graph import rag

# %%
print("documents:", None if DOCUMENTS is None else len(DOCUMENTS))
print("embeddings:", None if DOC_EMBEDDINGS is None else DOC_EMBEDDINGS.shape)
# Out:
# documents: 0
# embeddings: None

# %%
question = "What is google adk?"
answer, contexts, confidence = rag(question, DOCUMENTS, DOC_EMBEDDINGS, k=2)

print(f"Q: {question}")
print(f"A: {answer}")
print(f"Confidence: {confidence}")
# Out:
# 2026-02-05 17:22:47,673 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-05 17:22:48,797 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-05 17:22:51,305 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Q: What is google adk?
# A: Google ADK (Agent Development Kit) is a flexible, modular framework for developing, deploying, and orchestrating AI agents. It is designed to make agent development more like software development, allowing developers to create, deploy, and orchestrate agentic architectures for tasks ranging from simple to complex. It is optimized for Gemini and the Google ecosystem but is deployment-agnostic and compatible with other frameworks.
# Confidence: 0.59

# %%
question = "Who invented AI?"
answer, contexts, confidence = rag(question, DOCUMENTS, DOC_EMBEDDINGS, k=2)

print(f"Q: {question}")
print(f"A: {answer}")
print(f"Confidence: {confidence}")
# Out:
# 2026-02-05 17:23:02,827 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-05 17:23:05,410 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Q: Who invented AI?
# A: The context provided does not specify a single inventor of AI. It mentions Marvin Minsky as a cofounder of the MIT AI Lab, which advanced early robotics and cognitive models, but it does not attribute the invention of AI to him or any single individual. AI grew from deep mathematical ideas into practical systems, suggesting a collaborative and evolutionary development rather than a single inventor.
# Confidence: 0.62

# %%
question = "what is challange to intigrate langgraph with google adk?"
answer, contexts, confidence = rag(question, DOCUMENTS, DOC_EMBEDDINGS, k=2)

print(f"Q: {question}")
print(f"A: {answer}")
print(f"Confidence: {confidence}")
# Out:
# 2026-02-05 17:23:11,735 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-05 17:23:14,189 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Q: what is challange to intigrate langgraph with google adk?
# A: The challenge in integrating a LangGraph agent with Google ADK is that the LangGraph agent is integrated into ADK as a tool, and the Google ADK agent serves as the main orchestrator.
# Confidence: 0.49

# %%
question = "Who Is Narendra Modi?"
answer, contexts, confidence = rag(question, DOCUMENTS, DOC_EMBEDDINGS, k=2)

print(f"Q: {question}")
print(f"A: {answer}")
print(f"Confidence: {confidence}")
# Out:
# 2026-02-05 17:23:43,839 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-05 17:23:45,793 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Q: Who Is Narendra Modi?
# A: The context provided does not contain any information about Narendra Modi.
# Confidence: 0.15
